# %%
import pandas as pd
import numpy as np
data = pd.read_csv(r'E:\Seneca\240\MMT-2.csv')
dataset = pd.DataFrame(data)

# %%
dataset.head(50)
# Out:
#                              Uniq Id            Crawl Timestamp  \
# 0   0eaaee0a8a6ba47cfc9f6e6852fcf9f0  2019-09-19 23:07:23 +0000
# 1   c782c902e6d370153361d708bb2bca64  2019-09-25 16:15:44 +0000
# 2   1087ed9303d0ac724460088a5920065d  2019-09-26 04:18:42 +0000
# 3   3bda4788836d573910f605154ba949dc  2019-09-24 11:46:20 +0000
# 4   aab612682c998bde97e040b212cd5689  2019-09-25 12:45:50 +0000
# 5   6e4b1262dc56e466c3fa8ede946402f4  2019-09-17 08:11:19 +0000
# 6   e52caffea66a4f6d35028504d50bc523  2019-09-25 01:12:03 +0000
# 7   39eee4d2d77fd24f551a04449e102425  2019-09-23 10:36:27 +0000
# 8   504b2992a5ec5b3cf60536c7ab43ce42  2019-09-19 01:41:29 +0000
# 9   825cea031e226446310a8d517536f298  2019-09-26 09:01:08 +0000
# 10  6b8f001700f3fb1e212559d72d4d87c0  2019-09-23 11:01:50 +0000
# 11  961f2baaca32e421cebde82c683bf2ed  2019-09-20 06:11:55 +0000
# 12  6a5b4bc746475e2c0322bd46fc6ac321  2019-09-17 23:22:11 +0000
# 13  7f3f1de34e88f548517f1173d6378820  2019-09-16 19:51:59 +0000
# ...

# %%
df = pd.DataFrame(dataset)
df
# Out:
#                                 Uniq Id            Crawl Timestamp  \
# 0      0eaaee0a8a6ba47cfc9f6e6852fcf9f0  2019-09-19 23:07:23 +0000
# 1      c782c902e6d370153361d708bb2bca64  2019-09-25 16:15:44 +0000
# 2      1087ed9303d0ac724460088a5920065d  2019-09-26 04:18:42 +0000
# 3      3bda4788836d573910f605154ba949dc  2019-09-24 11:46:20 +0000
# 4      aab612682c998bde97e040b212cd5689  2019-09-25 12:45:50 +0000
# ...                                 ...                        ...
# 29995  4874c3f46d9334b3d702fb57b0e322b3  2019-09-20 09:19:38 +0000
# 29996  2f8b72d6321a705e6a701c01881208bc  2019-09-24 08:22:49 +0000
# 29997  1e7109a6ebab2470a9561517b326e741  2019-09-17 20:22:32 +0000
# 29998  4eb294e442c0c893736f35aa23c5683d  2019-09-18 00:45:04 +0000
# 29999  77179df7596ed97c7d22a53fc5bcda2c  2019-09-18 13:35:40 +0000
#
#                                             Package Name  \
# 0           A Grand Week in North East - Lachung Special
# ...

# %%
df = df.rename(columns={'Uniq Id': 'Uniq_Id', 'Package Name': 'Package_Name','Package Type': 'Package_Type','Places Covered': 'Places_Covered','Travel Date': 'Travel_Date','Start City': 'Start_City','Price Per Two Persons': 'Price_Per_Two_Persons','Per Person Price': 'Per_Person_Price'})

# %%
nValues = df.isna().sum()
nValues
# Out:
# Uniq_Id                            0
# Crawl Timestamp                    0
# Package_Name                       0
# Page Url                           0
# Package_Type                       0
# Company                            0
# Destination                        0
# Itinerary                          0
# Places_Covered                     0
# Travel_Date                        0
# Hotel Details                   4167
# Start_City                         0
# Airline                         7010
# Flight Stops                   30000
# Onwards Return Flight Time      7010
# Meals                          30000
# Price_Per_Two_Persons              0
# Per_Person_Price                   0
# Sightseeing Places Covered      2258
# Initial Payment For Booking    30000
# Cancellation Rules              1142
# Date Change Rules              30000
# Unnamed: 22                    30000
# Unnamed: 23                    27962
# dtype: int64

# %%
del df['Unnamed: 22']
del df['Date Change Rules']
del df['Flight Stops']
del df['Meals']
del df['Initial Payment For Booking']
del df['Cancellation Rules']
del df['Company']
del df['Crawl Timestamp']
df
# Out:
#                                 Uniq_Id  \
# 0      0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1      c782c902e6d370153361d708bb2bca64
# 2      1087ed9303d0ac724460088a5920065d
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# ...                                 ...
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package_Name  \
# 0           A Grand Week in North East - Lachung Special
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 2      Experiential Manali from Chandigarh (Candid Ph...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# ...                                                  ...
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# ...

# %%
df.rename(columns = {'Unnamed: 23' : 'Fees/Charges'}, inplace = True)
df
# Out:
#                                 Uniq_Id  \
# 0      0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1      c782c902e6d370153361d708bb2bca64
# 2      1087ed9303d0ac724460088a5920065d
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# ...                                 ...
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package_Name  \
# 0           A Grand Week in North East - Lachung Special
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 2      Experiential Manali from Chandigarh (Candid Ph...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# ...                                                  ...
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# ...

# %%
nValues1 = df.isna().sum()
nValues1
# Out:
# Uniq_Id                           0
# Package_Name                      0
# Page Url                          0
# Package_Type                      0
# Destination                       0
# Itinerary                         0
# Places_Covered                    0
# Travel_Date                       0
# Hotel Details                  4167
# Start_City                        0
# Airline                        7010
# Onwards Return Flight Time     7010
# Price_Per_Two_Persons             0
# Per_Person_Price                  0
# Sightseeing Places Covered     2258
# Fees/Charges                  27962
# dtype: int64

# %%
df = df.fillna(0)
df
# Out:
#                                 Uniq_Id  \
# 0      0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1      c782c902e6d370153361d708bb2bca64
# 2      1087ed9303d0ac724460088a5920065d
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# ...                                 ...
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package_Name  \
# 0           A Grand Week in North East - Lachung Special
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 2      Experiential Manali from Chandigarh (Candid Ph...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# ...                                                  ...
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# ...

# %%
df['Price_Per_Two_Persons'] = df['Price_Per_Two_Persons'].astype(float)

# %%
df.dtypes
# Out:
# Uniq_Id                        object
# Package_Name                   object
# Page Url                       object
# Package_Type                   object
# Destination                    object
# Itinerary                      object
# Places_Covered                 object
# Travel_Date                    object
# Hotel Details                  object
# Start_City                     object
# Airline                        object
# Onwards Return Flight Time     object
# Price_Per_Two_Persons         float64
# Per_Person_Price              float64
# Sightseeing Places Covered     object
# Fees/Charges                   object
# dtype: object

# %%
categorical = df.dtypes[df.dtypes == "object"].index
print(categorical)
df[categorical].describe()
# Out:
# Index(['Uniq_Id', 'Package_Name', 'Page Url', 'Package_Type', 'Destination',
#        'Itinerary', 'Places_Covered', 'Travel_Date', 'Hotel Details',
#        'Start_City', 'Airline', 'Onwards Return Flight Time',
#        'Sightseeing Places Covered', 'Fees/Charges'],
#       dtype='object')
#                                  Uniq_Id           Package_Name  \
# count                              30000                  30000
# unique                             30000                   2236
# top     0eaaee0a8a6ba47cfc9f6e6852fcf9f0  Bali Special 4 Nights
# freq                                   1                     53
#
#                                                  Page Url Package_Type  \
# count                                               30000        30000
# unique                                              27250         3638
# top     The Orchard Retreat & Spa:Five|The Khyber Hima...       Deluxe
# freq                                                   38         7442
#
# ...

# %%
df.duplicated(subset=['Page Url'])
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 29995    False
# 29996    False
# 29997    False
# 29998     True
# 29999    False
# Length: 30000, dtype: bool

# %%
print(df.duplicated(subset=['Page Url']).sum())
# Out:
# 2750

# %%
df['Travel_Date'] = pd.to_datetime(df['Travel_Date'], errors='coerce')

# %%
df.dtypes
# Out:
# Uniq_Id                               object
# Package_Name                          object
# Page Url                              object
# Package_Type                          object
# Destination                           object
# Itinerary                             object
# Places_Covered                        object
# Travel_Date                   datetime64[ns]
# Hotel Details                         object
# Start_City                            object
# Airline                               object
# Onwards Return Flight Time            object
# Price_Per_Two_Persons                float64
# Per_Person_Price                     float64
# Sightseeing Places Covered            object
# Fees/Charges                          object
# dtype: object

# %%
df
# Out:
#                                 Uniq_Id  \
# 0      0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1      c782c902e6d370153361d708bb2bca64
# 2      1087ed9303d0ac724460088a5920065d
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# ...                                 ...
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package_Name  \
# 0           A Grand Week in North East - Lachung Special
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 2      Experiential Manali from Chandigarh (Candid Ph...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# ...                                                  ...
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.catplot(x="Start_City", y="Price_Per_Two_Persons", data=df)

# %%
sns.catplot(x="Start_City", y="Per_Person_Price", data=df)

# %%
sns.catplot(x="Start_City", kind='count', data=df)

# %%
df
# Out:
#                                 Uniq_Id  \
# 0      0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1      c782c902e6d370153361d708bb2bca64
# 2      1087ed9303d0ac724460088a5920065d
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# ...                                 ...
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package_Name  \
# 0           A Grand Week in North East - Lachung Special
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 2      Experiential Manali from Chandigarh (Candid Ph...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# ...                                                  ...
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# ...

# %%
df.loc[df['Package_Type'] == 'Standard']
# Out:
#                                 Uniq_Id  \
# 1      c782c902e6d370153361d708bb2bca64
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# 6      e52caffea66a4f6d35028504d50bc523
# 7      39eee4d2d77fd24f551a04449e102425
# ...                                 ...
# 29981  3e90da81d853129b494d939bbfbd5a98
# 29986  4a4494b6def04addf2077e33b18e102c
# 29987  e2a8f75c6ff5deaf5d06361a838ffb77
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29998  4eb294e442c0c893736f35aa23c5683d
#
#                                             Package_Name  \
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# 6              A Journey to Cochin, Thekkady and Allepey
# 7                       A Retreat to Ooty and Kodaikanal
# ...                                                  ...
# 29981                          Sun and Sand in Sri Lanka
# ...

# %%
df.loc[df['Package_Type'].isin(['Premium','Luxury','Deluxe','Standard','Budget'])]
# Out:
#                                 Uniq_Id  \
# 0      0eaaee0a8a6ba47cfc9f6e6852fcf9f0
# 1      c782c902e6d370153361d708bb2bca64
# 2      1087ed9303d0ac724460088a5920065d
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# ...                                 ...
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29996  2f8b72d6321a705e6a701c01881208bc
# 29997  1e7109a6ebab2470a9561517b326e741
# 29998  4eb294e442c0c893736f35aa23c5683d
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package_Name  \
# 0           A Grand Week in North East - Lachung Special
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 2      Experiential Manali from Chandigarh (Candid Ph...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# ...                                                  ...
# 29995  Mewar Special - Horse Riding & Private Sunset ...
# ...

# %%
df.loc[(df['Per_Person_Price'] >= 15000) & (df['Price_Per_Two_Persons'] <= 60000)]
# Out:
#                                 Uniq_Id  \
# 1      c782c902e6d370153361d708bb2bca64
# 3      3bda4788836d573910f605154ba949dc
# 4      aab612682c998bde97e040b212cd5689
# 9      825cea031e226446310a8d517536f298
# 11     961f2baaca32e421cebde82c683bf2ed
# ...                                 ...
# 29991  b52298a2153163691288d9c716145f52
# 29992  1f3bca428ba534a212d4ed03a12ffda2
# 29994  14ee6a74a9a7b3aad64b6f81118b3d8f
# 29995  4874c3f46d9334b3d702fb57b0e322b3
# 29999  77179df7596ed97c7d22a53fc5bcda2c
#
#                                             Package_Name  \
# 1      A Relaxing holiday to Kerala - Free Speed Boat...
# 3                               Stunning Kashmir Holiday
# 4            Best of Holiday in Himachal from Chandigarh
# 9                         Kodaikanal and Madurai Holiday
# 11              A Vacation to South - Durga Puja Special
# ...                                                  ...
# 29991  Rajasthan Holiday with Dinner at a Lake View H...
# ...

# %%
df_custom = df.loc[(df['Travel_Date'] >= '2019-01-01') & (df['Travel_Date'] <= '2019-10-11') 
       & (df['Per_Person_Price'] >= 15000) & (df['Price_Per_Two_Persons'] <= 60000)]

# %%
df_custom[['Package_Name','Package_Type','Destination','Travel_Date','Start_City','Price_Per_Two_Persons','Per_Person_Price']]
# Out:
#                                             Package_Name Package_Type  \
# 1      A Relaxing holiday to Kerala - Free Speed Boat...     Standard
# 9                         Kodaikanal and Madurai Holiday      Premium
# 12      Goa 6N stay - with Transfers (for Bigger Groups)       Luxury
# 13      Kodaikanal with Ooty Special (Honeymoon Special)      Premium
# 19     Jaipur, Jodhpur and Udaipur in 6 Days - With F...      Premium
# ...                                                  ...          ...
# 29979            Kerala - A Lovers Paradise - Value Pack      Premium
# 29981                          Sun and Sand in Sri Lanka     Standard
# 29992                       Andaman and Havelock Special       Deluxe
# 29995  Mewar Special - Horse Riding & Private Sunset ...     Standard
# 29999  A splendid week in Shillong, Kaziranga, Guwaha...       Luxury
#
#                                              Destination Travel_Date  \
# ...
